# %%
import numpy as np
import os.path
from time import time
import types
import matplotlib.pyplot as plt

#import my_functions

# %%
# %matplotlib inline
# edit this line to change the figure size
plt.rcParams['figure.figsize'] = (16.0, 10.0)
# force auto-reload of import modules before running code 
# %load_ext autoreload
# %autoreload 2

# %%
I = plt.imread("./figs/car.png")

# %%
print(I.shape)
print(type(I))
# Out:
# (133, 301, 3)
# <class 'numpy.ndarray'>

# %%
# type conversion
I = I.astype(np.float32)

# %%
plt.imshow(I)

# %%
# visualiser en utilisant view surface
from view_surface import *
view_surface('./figs/car.png')
# Out:
# C:\Users\Lenovo\TPs_BTI\tp1\BTI\view_surface.py:21: MatplotlibDeprecationWarning: Calling gca() with keyword arguments was deprecated in Matplotlib 3.4. Starting two minor releases later, gca() will take no keyword arguments. The gca() function should only be used to get the current axes, or if no axes exist, create new axes with default keyword arguments. To create a new axes with non-default arguments, use plt.axes() or plt.subplot().
#   ax = fig.gca(projection='3d')

# %%
import my_functions as mf

# %%
#matrix and infos about image
rd_bird_file = "./figs/red_bird.png"
small_file = "./figs/bird_small.tiff"
(I,L,C)=mf.OpenImage(small_file)
plt.imshow(I)

# %%
#split canals
(I_red,I_green,I_blue) = mf.Divide(I)
plt.imshow(I_red)

# %%
#format hsv
image_hsv = mf.HSV(small_file)
plt.imshow(image_hsv)

# %%
#count pixels
mf.CountPix(small_file)
# Out:
# 16384

# %%
a=1
b=4
I_fact = mf.factPix(a,b,I)
plt.imshow(I_fact)

# %%
(loga_I,exp_I,carre_I) = mf.func_a(plt.imread(rd_bird_file))
# Out:
# C:\Users\Lenovo\TPs_BTI\tp1\BTI\my_functions.py:28: RuntimeWarning: divide by zero encountered in log2
#   loga = np.log2(I)

# %%
plt.imshow(mf.factPix(1.1,0,carre_I))
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
(mean_I,mean_I) = mf.func_m(I)
print(mean_I)
print(mean_I)
# Out:
# 75.2985080378663
# 75.2985080378663

# %%
plt.imshow(mf.normalize(I))
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
plt.imshow(mf.inverse(I))

# %%
h_I,bins_I = mf.calcHist(I)
print(h_I.shape,bins_I.shape)
plt.plot(h_I)
# Out:
# (256,) (257,)

# %%
plt.imshow(mf.thresHold(I,170))

# %%
mf.func_j(small_file)

# %%
mf.func_t(small_file)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 0

# %%
mf.func_f(small_file)
# Out:
# 0
